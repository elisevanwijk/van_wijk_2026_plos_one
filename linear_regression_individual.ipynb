# %%
# %load_ext jupyter_black

# %%
from linear_regression_individual import *

# %%
lr = LinearRegressionIndividal()

# %%
lr.generate_rm_results()
# Out:
# Loading RM 2021, ejected 0 for gpa availability, 30 for having 75% of ects available, resulting in 322
# Loading RM 2022, ejected 0 for gpa availability, 3 for having 75% of ects available, resulting in 295
# Loading RM 2023, ejected 0 for gpa availability, 7 for having 75% of ects available, resulting in 285

# %%
lr.generate_rm_dm_results()
# Out:
# Loading RM 2021_DA 2022, ejected 0 for gpa availability, 4 for having 75% of ects available, resulting in 282
# Loading RM 2022_DA 2023, ejected 0 for gpa availability, 1 for having 75% of ects available, resulting in 255
# Loading RM 2023_DA 2024, ejected 0 for gpa availability, 6 for having 75% of ects available, resulting in 260

# %%
lr.report_classify_per_cohort_rm()
# Out:
# RM 2021
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     gpa_last_attempt_year_1   R-squared:                       0.627
# Model:                                 OLS   Adj. R-squared:                  0.626
# Method:                      Least Squares   F-statistic:                     537.3
# Date:                     Fri, 24 Apr 2026   Prob (F-statistic):           1.86e-70
# Time:                             18:28:42   Log-Likelihood:                -253.41
# No. Observations:                      322   AIC:                             510.8
# Df Residuals:                          320   BIC:                             518.4
# Df Model:                                1
# Covariance Type:                 nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  6.9194      0.030    232.860      0.000       6.861       6.978
# z_score_Invulvraag     0.6899      0.030     23.181      0.000       0.631       0.748
# ==============================================================================
# Omnibus:                        1.396   Durbin-Watson:                   2.182
# Prob(Omnibus):                  0.497   Jarque-Bera (JB):                1.127
# Skew:                          -0.096   Prob(JB):                        0.569
# Kurtosis:                       3.216   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     gpa_last_attempt_year_1   R-squared:                       0.425
# Model:                                 OLS   Adj. R-squared:                  0.423
# Method:                      Least Squares   F-statistic:                     236.1
# Date:                     Fri, 24 Apr 2026   Prob (F-statistic):           2.68e-40
# Time:                             18:28:42   Log-Likelihood:                -323.10
# No. Observations:                      322   AIC:                             650.2
# Df Residuals:                          320   BIC:                             657.7
# Df Model:                                1
# Covariance Type:                 nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      6.9194      0.037    187.545      0.000       6.847       6.992
# z_score_Meerkeuzevraag     0.5678      0.037     15.367      0.000       0.495       0.641
# ==============================================================================
# Omnibus:                        0.542   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.763   Jarque-Bera (JB):                0.667
# Skew:                           0.057   Prob(JB):                        0.716
# Kurtosis:                       2.809   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     gpa_first_attempt_year_1   R-squared:                       0.622
# Model:                                  OLS   Adj. R-squared:                  0.621
# Method:                       Least Squares   F-statistic:                     526.8
# Date:                      Fri, 24 Apr 2026   Prob (F-statistic):           1.35e-69
# Time:                              18:28:42   Log-Likelihood:                -304.51
# No. Observations:                       322   AIC:                             613.0
# Df Residuals:                           320   BIC:                             620.6
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  6.7392      0.035    193.513      0.000       6.671       6.808
# z_score_Invulvraag     0.8006      0.035     22.952      0.000       0.732       0.869
# ==============================================================================
# Omnibus:                        1.274   Durbin-Watson:                   2.192
# Prob(Omnibus):                  0.529   Jarque-Bera (JB):                1.097
# Skew:                          -0.138   Prob(JB):                        0.578
# Kurtosis:                       3.073   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     gpa_first_attempt_year_1   R-squared:                       0.439
# Model:                                  OLS   Adj. R-squared:                  0.437
# Method:                       Least Squares   F-statistic:                     250.4
# Date:                      Fri, 24 Apr 2026   Prob (F-statistic):           4.63e-42
# Time:                              18:28:42   Log-Likelihood:                -368.14
# No. Observations:                       322   AIC:                             740.3
# Df Residuals:                           320   BIC:                             747.8
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      6.7392      0.042    158.816      0.000       6.656       6.823
# z_score_Meerkeuzevraag     0.6725      0.042     15.823      0.000       0.589       0.756
# ==============================================================================
# Omnibus:                        0.547   Durbin-Watson:                   2.041
# Prob(Omnibus):                  0.761   Jarque-Bera (JB):                0.665
# Skew:                           0.033   Prob(JB):                        0.717
# Kurtosis:                       2.788   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# RM 2022
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     gpa_last_attempt_year_1   R-squared:                       0.613
# Model:                                 OLS   Adj. R-squared:                  0.611
# Method:                      Least Squares   F-statistic:                     463.5
# Date:                     Fri, 24 Apr 2026   Prob (F-statistic):           2.63e-62
# Time:                             18:28:42   Log-Likelihood:                -257.49
# No. Observations:                      295   AIC:                             519.0
# Df Residuals:                          293   BIC:                             526.4
# Df Model:                                1
# Covariance Type:                 nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  6.6517      0.034    196.575      0.000       6.585       6.718
# z_score_Invulvraag     0.7298      0.034     21.530      0.000       0.663       0.796
# ==============================================================================
# Omnibus:                        6.143   Durbin-Watson:                   2.056
# Prob(Omnibus):                  0.046   Jarque-Bera (JB):                6.818
# Skew:                          -0.223   Prob(JB):                       0.0331
# Kurtosis:                       3.597   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     gpa_last_attempt_year_1   R-squared:                       0.566
# Model:                                 OLS   Adj. R-squared:                  0.565
# Method:                      Least Squares   F-statistic:                     382.8
# Date:                     Fri, 24 Apr 2026   Prob (F-statistic):           4.11e-55
# Time:                             18:28:42   Log-Likelihood:                -274.13
# No. Observations:                      295   AIC:                             552.3
# Df Residuals:                          293   BIC:                             559.6
# Df Model:                                1
# Covariance Type:                 nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      6.6517      0.036    185.795      0.000       6.581       6.722
# z_score_Meerkeuzevraag     0.7017      0.036     19.566      0.000       0.631       0.772
# ==============================================================================
# Omnibus:                        0.613   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.736   Jarque-Bera (JB):                0.738
# Skew:                          -0.076   Prob(JB):                        0.692
# Kurtosis:                       2.807   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     gpa_first_attempt_year_1   R-squared:                       0.633
# Model:                                  OLS   Adj. R-squared:                  0.632
# Method:                       Least Squares   F-statistic:                     505.3
# Date:                      Fri, 24 Apr 2026   Prob (F-statistic):           9.93e-66
# Time:                              18:28:42   Log-Likelihood:                -310.26
# No. Observations:                       295   AIC:                             624.5
# Df Residuals:                           293   BIC:                             631.9
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  6.3618      0.040    157.213      0.000       6.282       6.441
# z_score_Invulvraag     0.9112      0.041     22.478      0.000       0.831       0.991
# ==============================================================================
# Omnibus:                        7.600   Durbin-Watson:                   2.041
# Prob(Omnibus):                  0.022   Jarque-Bera (JB):                7.869
# Skew:                          -0.395   Prob(JB):                       0.0196
# Kurtosis:                       2.869   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     gpa_first_attempt_year_1   R-squared:                       0.577
# Model:                                  OLS   Adj. R-squared:                  0.576
# Method:                       Least Squares   F-statistic:                     399.9
# Date:                      Fri, 24 Apr 2026   Prob (F-statistic):           1.05e-56
# Time:                              18:28:42   Log-Likelihood:                -331.13
# No. Observations:                       295   AIC:                             666.3
# Df Residuals:                           293   BIC:                             673.6
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      6.3618      0.043    146.474      0.000       6.276       6.447
# z_score_Meerkeuzevraag     0.8701      0.044     19.999      0.000       0.784       0.956
# ==============================================================================
# Omnibus:                        5.893   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.053   Jarque-Bera (JB):                3.804
# Skew:                          -0.096   Prob(JB):                        0.149
# Kurtosis:                       2.478   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# RM 2023
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     gpa_last_attempt_year_1   R-squared:                       0.645
# Model:                                 OLS   Adj. R-squared:                  0.643
# Method:                      Least Squares   F-statistic:                     513.6
# Date:                     Fri, 24 Apr 2026   Prob (F-statistic):           1.48e-65
# Time:                             18:28:42   Log-Likelihood:                -242.52
# No. Observations:                      285   AIC:                             489.0
# Df Residuals:                          283   BIC:                             496.3
# Df Model:                                1
# Covariance Type:                 nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  6.6372      0.034    197.041      0.000       6.571       6.703
# z_score_Invulvraag     0.7647      0.034     22.663      0.000       0.698       0.831
# ==============================================================================
# Omnibus:                       14.082   Durbin-Watson:                   2.236
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.641
# Skew:                          -0.435   Prob(JB):                     0.000243
# Kurtosis:                       3.803   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     gpa_last_attempt_year_1   R-squared:                       0.556
# Model:                                 OLS   Adj. R-squared:                  0.555
# Method:                      Least Squares   F-statistic:                     355.0
# Date:                     Fri, 24 Apr 2026   Prob (F-statistic):           7.10e-52
# Time:                             18:28:42   Log-Likelihood:                -274.16
# No. Observations:                      285   AIC:                             552.3
# Df Residuals:                          283   BIC:                             559.6
# Df Model:                                1
# Covariance Type:                 nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      6.6372      0.038    176.332      0.000       6.563       6.711
# z_score_Meerkeuzevraag     0.7104      0.038     18.840      0.000       0.636       0.785
# ==============================================================================
# Omnibus:                       13.025   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               17.852
# Skew:                          -0.348   Prob(JB):                     0.000133
# Kurtosis:                       4.010   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     gpa_first_attempt_year_1   R-squared:                       0.673
# Model:                                  OLS   Adj. R-squared:                  0.672
# Method:                       Least Squares   F-statistic:                     583.1
# Date:                      Fri, 24 Apr 2026   Prob (F-statistic):           1.06e-70
# Time:                              18:28:42   Log-Likelihood:                -281.19
# No. Observations:                       285   AIC:                             566.4
# Df Residuals:                           283   BIC:                             573.7
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  6.3942      0.039    165.738      0.000       6.318       6.470
# z_score_Invulvraag     0.9332      0.039     24.147      0.000       0.857       1.009
# ==============================================================================
# Omnibus:                        6.989   Durbin-Watson:                   2.308
# Prob(Omnibus):                  0.030   Jarque-Bera (JB):                6.766
# Skew:                          -0.359   Prob(JB):                       0.0339
# Kurtosis:                       3.230   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     gpa_first_attempt_year_1   R-squared:                       0.580
# Model:                                  OLS   Adj. R-squared:                  0.578
# Method:                       Least Squares   F-statistic:                     390.4
# Date:                      Fri, 24 Apr 2026   Prob (F-statistic):           3.31e-55
# Time:                              18:28:42   Log-Likelihood:                -317.05
# No. Observations:                       285   AIC:                             638.1
# Df Residuals:                           283   BIC:                             645.4
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      6.3942      0.044    146.143      0.000       6.308       6.480
# z_score_Meerkeuzevraag     0.8660      0.044     19.759      0.000       0.780       0.952
# ==============================================================================
# Omnibus:                        4.081   Durbin-Watson:                   2.115
# Prob(Omnibus):                  0.130   Jarque-Bera (JB):                3.799
# Skew:                          -0.273   Prob(JB):                        0.150
# Kurtosis:                       3.145   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
lr.report_classify_per_cohort_rm_dm()
# Out:
# RM 2021_DA 2022
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     gpa_last_attempt_total   R-squared:                       0.678
# Model:                                OLS   Adj. R-squared:                  0.677
# Method:                     Least Squares   F-statistic:                     590.9
# Date:                    Fri, 24 Apr 2026   Prob (F-statistic):           5.87e-71
# Time:                            18:28:42   Log-Likelihood:                -168.42
# No. Observations:                     282   AIC:                             340.8
# Df Residuals:                         280   BIC:                             348.1
# Df Model:                               1
# Covariance Type:                nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  6.8364      0.026    260.177      0.000       6.785       6.888
# z_score_Invulvraag     0.6399      0.026     24.308      0.000       0.588       0.692
# ==============================================================================
# Omnibus:                        1.008   Durbin-Watson:                   2.035
# Prob(Omnibus):                  0.604   Jarque-Bera (JB):                0.750
# Skew:                          -0.099   Prob(JB):                        0.687
# Kurtosis:                       3.157   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     gpa_last_attempt_total   R-squared:                       0.609
# Model:                                OLS   Adj. R-squared:                  0.608
# Method:                     Least Squares   F-statistic:                     436.6
# Date:                    Fri, 24 Apr 2026   Prob (F-statistic):           4.46e-59
# Time:                            18:28:42   Log-Likelihood:                -195.92
# No. Observations:                     282   AIC:                             395.8
# Df Residuals:                         280   BIC:                             403.1
# Df Model:                               1
# Covariance Type:                nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      6.8364      0.029    236.004      0.000       6.779       6.893
# z_score_Meerkeuzevraag     0.6063      0.029     20.894      0.000       0.549       0.663
# ==============================================================================
# Omnibus:                        0.708   Durbin-Watson:                   2.057
# Prob(Omnibus):                  0.702   Jarque-Bera (JB):                0.469
# Skew:                           0.067   Prob(JB):                        0.791
# Kurtosis:                       3.148   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     gpa_first_attempt_total   R-squared:                       0.708
# Model:                                 OLS   Adj. R-squared:                  0.707
# Method:                      Least Squares   F-statistic:                     679.2
# Date:                     Fri, 24 Apr 2026   Prob (F-statistic):           7.69e-77
# Time:                             18:28:42   Log-Likelihood:                -197.08
# No. Observations:                      282   AIC:                             398.2
# Df Residuals:                          280   BIC:                             405.4
# Df Model:                                1
# Covariance Type:                 nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  6.6662      0.029    229.179      0.000       6.609       6.723
# z_score_Invulvraag     0.7594      0.029     26.062      0.000       0.702       0.817
# ==============================================================================
# Omnibus:                        1.007   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.604   Jarque-Bera (JB):                1.061
# Skew:                          -0.065   Prob(JB):                        0.588
# Kurtosis:                       2.729   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     gpa_first_attempt_total   R-squared:                       0.632
# Model:                                 OLS   Adj. R-squared:                  0.631
# Method:                      Least Squares   F-statistic:                     481.1
# Date:                     Fri, 24 Apr 2026   Prob (F-statistic):           9.54e-63
# Time:                             18:28:42   Log-Likelihood:                -229.71
# No. Observations:                      282   AIC:                             463.4
# Df Residuals:                          280   BIC:                             470.7
# Df Model:                                1
# Covariance Type:                 nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      6.6662      0.033    204.140      0.000       6.602       6.730
# z_score_Meerkeuzevraag     0.7175      0.033     21.933      0.000       0.653       0.782
# ==============================================================================
# Omnibus:                        0.164   Durbin-Watson:                   2.041
# Prob(Omnibus):                  0.921   Jarque-Bera (JB):                0.271
# Skew:                           0.045   Prob(JB):                        0.873
# Kurtosis:                       2.877   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# RM 2022_DA 2023
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     gpa_last_attempt_total   R-squared:                       0.680
# Model:                                OLS   Adj. R-squared:                  0.679
# Method:                     Least Squares   F-statistic:                     537.3
# Date:                    Fri, 24 Apr 2026   Prob (F-statistic):           1.62e-64
# Time:                            18:28:42   Log-Likelihood:                -152.64
# No. Observations:                     255   AIC:                             309.3
# Df Residuals:                         253   BIC:                             316.4
# Df Model:                               1
# Covariance Type:                nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  6.8837      0.028    248.687      0.000       6.829       6.938
# z_score_Invulvraag     0.6429      0.028     23.179      0.000       0.588       0.697
# ==============================================================================
# Omnibus:                        0.567   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.753   Jarque-Bera (JB):                0.401
# Skew:                          -0.090   Prob(JB):                        0.819
# Kurtosis:                       3.072   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     gpa_last_attempt_total   R-squared:                       0.664
# Model:                                OLS   Adj. R-squared:                  0.663
# Method:                     Least Squares   F-statistic:                     500.9
# Date:                    Fri, 24 Apr 2026   Prob (F-statistic):           6.36e-62
# Time:                            18:28:42   Log-Likelihood:                -158.65
# No. Observations:                     255   AIC:                             321.3
# Df Residuals:                         253   BIC:                             328.4
# Df Model:                               1
# Covariance Type:                nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      6.8837      0.028    242.898      0.000       6.828       6.940
# z_score_Meerkeuzevraag     0.6355      0.028     22.381      0.000       0.580       0.691
# ==============================================================================
# Omnibus:                        1.961   Durbin-Watson:                   2.161
# Prob(Omnibus):                  0.375   Jarque-Bera (JB):                1.646
# Skew:                          -0.175   Prob(JB):                        0.439
# Kurtosis:                       3.180   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     gpa_first_attempt_total   R-squared:                       0.709
# Model:                                 OLS   Adj. R-squared:                  0.708
# Method:                      Least Squares   F-statistic:                     616.6
# Date:                     Fri, 24 Apr 2026   Prob (F-statistic):           8.79e-70
# Time:                             18:28:42   Log-Likelihood:                -180.70
# No. Observations:                      255   AIC:                             365.4
# Df Residuals:                          253   BIC:                             372.5
# Df Model:                                1
# Covariance Type:                 nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  6.7021      0.031    216.896      0.000       6.641       6.763
# z_score_Invulvraag     0.7688      0.031     24.832      0.000       0.708       0.830
# ==============================================================================
# Omnibus:                        0.831   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.660   Jarque-Bera (JB):                0.949
# Skew:                          -0.102   Prob(JB):                        0.622
# Kurtosis:                       2.782   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     gpa_first_attempt_total   R-squared:                       0.674
# Model:                                 OLS   Adj. R-squared:                  0.673
# Method:                      Least Squares   F-statistic:                     522.6
# Date:                     Fri, 24 Apr 2026   Prob (F-statistic):           1.75e-63
# Time:                             18:28:42   Log-Likelihood:                -195.29
# No. Observations:                      255   AIC:                             394.6
# Df Residuals:                          253   BIC:                             401.7
# Df Model:                                1
# Covariance Type:                 nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      6.7021      0.033    204.835      0.000       6.638       6.767
# z_score_Meerkeuzevraag     0.7494      0.033     22.860      0.000       0.685       0.814
# ==============================================================================
# Omnibus:                        6.323   Durbin-Watson:                   2.142
# Prob(Omnibus):                  0.042   Jarque-Bera (JB):                6.455
# Skew:                          -0.287   Prob(JB):                       0.0397
# Kurtosis:                       3.527   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# RM 2023_DA 2024
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     gpa_last_attempt_total   R-squared:                       0.706
# Model:                                OLS   Adj. R-squared:                  0.705
# Method:                     Least Squares   F-statistic:                     620.8
# Date:                    Fri, 24 Apr 2026   Prob (F-statistic):           1.28e-70
# Time:                            18:28:42   Log-Likelihood:                -169.40
# No. Observations:                     260   AIC:                             342.8
# Df Residuals:                         258   BIC:                             349.9
# Df Model:                               1
# Covariance Type:                nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  6.6939      0.029    231.611      0.000       6.637       6.751
# z_score_Invulvraag     0.7215      0.029     24.916      0.000       0.664       0.779
# ==============================================================================
# Omnibus:                       19.241   Durbin-Watson:                   1.903
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.981
# Skew:                          -0.496   Prob(JB):                     8.39e-07
# Kurtosis:                       4.264   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     gpa_last_attempt_total   R-squared:                       0.588
# Model:                                OLS   Adj. R-squared:                  0.586
# Method:                     Least Squares   F-statistic:                     367.6
# Date:                    Fri, 24 Apr 2026   Prob (F-statistic):           1.53e-51
# Time:                            18:28:42   Log-Likelihood:                -213.58
# No. Observations:                     260   AIC:                             431.2
# Df Residuals:                         258   BIC:                             438.3
# Df Model:                               1
# Covariance Type:                nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      6.6939      0.034    195.417      0.000       6.626       6.761
# z_score_Meerkeuzevraag     0.6580      0.034     19.173      0.000       0.590       0.726
# ==============================================================================
# Omnibus:                        9.422   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):               11.491
# Skew:                          -0.312   Prob(JB):                      0.00320
# Kurtosis:                       3.819   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     gpa_first_attempt_total   R-squared:                       0.711
# Model:                                 OLS   Adj. R-squared:                  0.710
# Method:                      Least Squares   F-statistic:                     635.0
# Date:                     Fri, 24 Apr 2026   Prob (F-statistic):           1.62e-71
# Time:                             18:28:42   Log-Likelihood:                -207.66
# No. Observations:                      260   AIC:                             419.3
# Df Residuals:                          258   BIC:                             426.5
# Df Model:                                1
# Covariance Type:                 nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  6.5006      0.033    194.145      0.000       6.435       6.567
# z_score_Invulvraag     0.8454      0.034     25.199      0.000       0.779       0.911
# ==============================================================================
# Omnibus:                        4.340   Durbin-Watson:                   1.888
# Prob(Omnibus):                  0.114   Jarque-Bera (JB):                4.096
# Skew:                          -0.303   Prob(JB):                        0.129
# Kurtosis:                       3.107   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     gpa_first_attempt_total   R-squared:                       0.601
# Model:                                 OLS   Adj. R-squared:                  0.599
# Method:                      Least Squares   F-statistic:                     388.5
# Date:                     Fri, 24 Apr 2026   Prob (F-statistic):           2.18e-53
# Time:                             18:28:42   Log-Likelihood:                -249.65
# No. Observations:                      260   AIC:                             503.3
# Df Residuals:                          258   BIC:                             510.4
# Df Model:                                1
# Covariance Type:                 nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      6.5006      0.039    165.194      0.000       6.423       6.578
# z_score_Meerkeuzevraag     0.7771      0.039     19.711      0.000       0.700       0.855
# ==============================================================================
# Omnibus:                        6.001   Durbin-Watson:                   2.046
# Prob(Omnibus):                  0.050   Jarque-Bera (JB):                5.701
# Skew:                          -0.338   Prob(JB):                       0.0578
# Kurtosis:                       3.265   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
lr.report_classify_rm_total()
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     gpa_last_attempt_year_1   R-squared:                       0.614
# Model:                                 OLS   Adj. R-squared:                  0.614
# Method:                      Least Squares   F-statistic:                     1433.
# Date:                     Fri, 24 Apr 2026   Prob (F-statistic):          2.21e-188
# Time:                             18:28:42   Log-Likelihood:                -780.37
# No. Observations:                      902   AIC:                             1565.
# Df Residuals:                          900   BIC:                             1574.
# Df Model:                                1
# Covariance Type:                 nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  6.7427      0.019    351.932      0.000       6.705       6.780
# z_score_Invulvraag     0.7266      0.019     37.860      0.000       0.689       0.764
# ==============================================================================
# Omnibus:                       21.718   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.071
# Skew:                          -0.271   Prob(JB):                     8.02e-07
# Kurtosis:                       3.673   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     gpa_last_attempt_year_1   R-squared:                       0.502
# Model:                                 OLS   Adj. R-squared:                  0.501
# Method:                      Least Squares   F-statistic:                     906.3
# Date:                     Fri, 24 Apr 2026   Prob (F-statistic):          2.68e-138
# Time:                             18:28:42   Log-Likelihood:                -895.84
# No. Observations:                      902   AIC:                             1796.
# Df Residuals:                          900   BIC:                             1805.
# Df Model:                                1
# Covariance Type:                 nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      6.7427      0.022    309.642      0.000       6.700       6.785
# z_score_Meerkeuzevraag     0.6566      0.022     30.105      0.000       0.614       0.699
# ==============================================================================
# Omnibus:                        5.154   Durbin-Watson:                   1.936
# Prob(Omnibus):                  0.076   Jarque-Bera (JB):                6.331
# Skew:                          -0.039   Prob(JB):                       0.0422
# Kurtosis:                       3.403   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     gpa_first_attempt_year_1   R-squared:                       0.625
# Model:                                  OLS   Adj. R-squared:                  0.624
# Method:                       Least Squares   F-statistic:                     1498.
# Date:                      Fri, 24 Apr 2026   Prob (F-statistic):          9.39e-194
# Time:                              18:28:42   Log-Likelihood:                -931.79
# No. Observations:                       902   AIC:                             1868.
# Df Residuals:                           900   BIC:                             1877.
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  6.5067      0.023    287.133      0.000       6.462       6.551
# z_score_Invulvraag     0.8786      0.023     38.709      0.000       0.834       0.923
# ==============================================================================
# Omnibus:                       16.979   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               17.613
# Skew:                          -0.313   Prob(JB):                     0.000150
# Kurtosis:                       3.278   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     gpa_first_attempt_year_1   R-squared:                       0.516
# Model:                                  OLS   Adj. R-squared:                  0.515
# Method:                       Least Squares   F-statistic:                     958.1
# Date:                      Fri, 24 Apr 2026   Prob (F-statistic):          7.88e-144
# Time:                              18:28:42   Log-Likelihood:                -1046.9
# No. Observations:                       902   AIC:                             2098.
# Df Residuals:                           900   BIC:                             2107.
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      6.5067      0.026    252.731      0.000       6.456       6.557
# z_score_Meerkeuzevraag     0.7982      0.026     30.953      0.000       0.748       0.849
# ==============================================================================
# Omnibus:                        0.714   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.700   Jarque-Bera (JB):                0.578
# Skew:                          -0.030   Prob(JB):                        0.749
# Kurtosis:                       3.109   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
lr.report_classify_rm_dm_total()
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     gpa_last_attempt_total   R-squared:                       0.680
# Model:                                OLS   Adj. R-squared:                  0.680
# Method:                     Least Squares   F-statistic:                     1692.
# Date:                    Fri, 24 Apr 2026   Prob (F-statistic):          4.28e-199
# Time:                            18:28:42   Log-Likelihood:                -506.11
# No. Observations:                     797   AIC:                             1016.
# Df Residuals:                         795   BIC:                             1026.
# Df Model:                               1
# Covariance Type:                nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  6.8051      0.016    420.209      0.000       6.773       6.837
# z_score_Invulvraag     0.6675      0.016     41.137      0.000       0.636       0.699
# ==============================================================================
# Omnibus:                       17.320   Durbin-Watson:                   1.919
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.568
# Skew:                          -0.227   Prob(JB):                     7.63e-06
# Kurtosis:                       3.710   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     gpa_last_attempt_total   R-squared:                       0.611
# Model:                                OLS   Adj. R-squared:                  0.611
# Method:                     Least Squares   F-statistic:                     1249.
# Date:                    Fri, 24 Apr 2026   Prob (F-statistic):          3.48e-165
# Time:                            18:28:42   Log-Likelihood:                -584.34
# No. Observations:                     797   AIC:                             1173.
# Df Residuals:                         795   BIC:                             1182.
# Df Model:                               1
# Covariance Type:                nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      6.8051      0.018    380.925      0.000       6.770       6.840
# z_score_Meerkeuzevraag     0.6325      0.018     35.341      0.000       0.597       0.668
# ==============================================================================
# Omnibus:                       15.651   Durbin-Watson:                   2.034
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.630
# Skew:                          -0.217   Prob(JB):                     3.31e-05
# Kurtosis:                       3.658   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     gpa_first_attempt_total   R-squared:                       0.702
# Model:                                 OLS   Adj. R-squared:                  0.701
# Method:                      Least Squares   F-statistic:                     1871.
# Date:                     Fri, 24 Apr 2026   Prob (F-statistic):          4.39e-211
# Time:                             18:28:42   Log-Likelihood:                -600.90
# No. Observations:                      797   AIC:                             1206.
# Df Residuals:                          795   BIC:                             1215.
# Df Model:                                1
# Covariance Type:                 nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  6.6237      0.018    363.146      0.000       6.588       6.659
# z_score_Invulvraag     0.7905      0.018     43.256      0.000       0.755       0.826
# ==============================================================================
# Omnibus:                        5.796   Durbin-Watson:                   1.899
# Prob(Omnibus):                  0.055   Jarque-Bera (JB):                5.719
# Skew:                          -0.206   Prob(JB):                       0.0573
# Kurtosis:                       3.050   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     gpa_first_attempt_total   R-squared:                       0.627
# Model:                                 OLS   Adj. R-squared:                  0.627
# Method:                      Least Squares   F-statistic:                     1337.
# Date:                     Fri, 24 Apr 2026   Prob (F-statistic):          1.92e-172
# Time:                             18:28:42   Log-Likelihood:                -690.04
# No. Observations:                      797   AIC:                             1384.
# Df Residuals:                          795   BIC:                             1393.
# Df Model:                                1
# Covariance Type:                 nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      6.6237      0.020    324.719      0.000       6.584       6.664
# z_score_Meerkeuzevraag     0.7472      0.020     36.560      0.000       0.707       0.787
# ==============================================================================
# Omnibus:                       13.928   Durbin-Watson:                   2.040
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.062
# Skew:                          -0.269   Prob(JB):                     0.000536
# Kurtosis:                       3.405   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
